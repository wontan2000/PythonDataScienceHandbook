# %% [markdown]
# <a href="https://colab.research.google.com/github/wontan2000/Python_textbook/blob/master/Index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 문자열(object)을 datetime64 타입으로 변경
df['일자'] = pd.to_datetime(df['일자'], format="%Y-%m-%d", errors="raise")

# %%
import pandas_datareader as pdr

import numpy as np
import pandas as pd
pdr.get_data_fred('GS10')
# Out:
#             GS10
# DATE
# 2015-09-01  2.17
# 2015-10-01  2.07
# 2015-11-01  2.26
# 2015-12-01  2.24
# 2016-01-01  2.09
# 2016-02-01  1.78
# 2016-03-01  1.89
# 2016-04-01  1.81
# 2016-05-01  1.81
# 2016-06-01  1.64
# 2016-07-01  1.50
# 2016-08-01  1.56
# 2016-09-01  1.63
# 2016-10-01  1.76
# 2016-11-01  2.14
# 2016-12-01  2.49
# 2017-01-01  2.43
# 2017-02-01  2.42
# 2017-03-01  2.48
# 2017-04-01  2.30
# 2017-05-01  2.30
# 2017-06-01  2.19
# 2017-07-01  2.32
# 2017-08-01  2.21
# 2017-09-01  2.20
# 2017-10-01  2.36
# 2017-11-01  2.35
# 2017-12-01  2.40
# 2018-01-01  2.58
# 2018-02-01  2.86
# 2018-03-01  2.84
# 2018-04-01  2.87
# 2018-05-01  2.98
# 2018-06-01  2.91
# 2018-07-01  2.89
# 2018-08-01  2.89
# 2018-09-01  3.00
# 2018-10-01  3.15
# 2018-11-01  3.12
# 2018-12-01  2.83
# 2019-01-01  2.71
# 2019-02-01  2.68
# 2019-03-01  2.57
# 2019-04-01  2.53
# 2019-05-01  2.40
# 2019-06-01  2.07
# 2019-07-01  2.06
# 2019-08-01  1.63
# 2019-09-01  1.70
# 2019-10-01  1.71
# 2019-11-01  1.81
# ...

# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd

# %%
start_date = '2004-08-19'
end_date = '2020-07-31'
shop_data = data.DataReader('SHOP','yahoo', start_date, end_date)
shop_data.head(9)
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2015-05-20  17.000000  17.000000  17.000000  17.000000         0  17.000000
# 2015-05-21  28.740000  24.110001  28.000000  25.680000  12303900  25.680000
# 2015-05-22  31.100000  26.000000  26.070000  28.309999   2841200  28.309999
# 2015-05-26  30.340000  29.080000  29.799999  29.650000    820200  29.650000
# 2015-05-27  30.809999  27.000000  30.670000  27.500000    797600  27.500000
# 2015-05-28  27.740000  26.480000  27.549999  27.450001    400000  27.450001
# 2015-05-29  27.379999  26.870001  27.250000  27.200001    255400  27.200001
# 2015-06-01  27.440001  26.600000  27.200001  27.330000    256900  27.330000
# 2015-06-02  27.469999  26.650000  27.469999  26.950001    379800  26.950001

# %%
shop_data.tail(9)
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-07-21  1024.979980   948.210022  1022.219971   952.830017  3038600
# 2020-07-22   980.570007   940.000000   964.729980   957.330017  2182100
# 2020-07-23   979.989990   911.119995   966.820007   928.409973  3017300
# 2020-07-24   941.840027   883.179993   906.000000   929.809998  2418800
# 2020-07-27   977.460022   935.140015   947.570007   976.390015  2689900
# 2020-07-28  1014.905029   975.169983  1007.090027   985.000000  3847400
# 2020-07-29  1107.920044  1038.000000  1107.380005  1053.589966  6492300
# 2020-07-30  1062.130005  1003.005005  1048.300049  1048.839966  2783900
# 2020-07-31  1067.677002  1012.109985  1065.000000  1024.000000  2332500
#
#               Adj Close
# Date
# 2020-07-21   952.830017
# 2020-07-22   957.330017
# 2020-07-23   928.409973
# 2020-07-24   929.809998
# 2020-07-27   976.390015
# 2020-07-28   985.000000
# 2020-07-29  1053.589966
# 2020-07-30  1048.839966
# ...

# %%
shop_data['Close'].plot()

# %%
start_date = '2004-08-01'
end_date = '2020-07-31'
NASDAQ_data = data.DataReader('^IXIC','yahoo', start_date, end_date)
NASDAQ_data.tail(9)
# Out:
#                     High           Low          Open         Close  \
# Date
# 2020-07-21  10839.929688  10650.459961  10837.879883  10680.360352
# 2020-07-22  10745.320312  10627.450195  10687.580078  10706.129883
# 2020-07-23  10728.120117  10407.870117  10689.500000  10461.419922
# 2020-07-24  10418.750000  10217.309570  10294.410156  10363.179688
# 2020-07-27  10546.440430  10399.860352  10421.700195  10536.269531
# 2020-07-28  10523.639648  10397.870117  10509.200195  10402.089844
# 2020-07-29  10567.910156  10464.000000  10474.700195  10542.940430
# 2020-07-30  10609.589844  10412.089844  10450.120117  10587.809570
# 2020-07-31  10747.799805  10557.700195  10741.469727  10745.269531
#
#                 Volume     Adj Close
# Date
# 2020-07-21  5311750000  10680.360352
# 2020-07-22  4074020000  10706.129883
# 2020-07-23  4469470000  10461.419922
# 2020-07-24  4205330000  10363.179688
# 2020-07-27  4209900000  10536.269531
# 2020-07-28  3869230000  10402.089844
# ...

# %%
NASDAQ_data['Close'].plot()

# %%
kstart_date = '2018-02-28'
kend_date = '2020-04-17'
kosdaqi = data.DataReader('251340.ks', 'yahoo', kstart_date, kend_date)
kosdaqi.head(9)
kosdaqi['Close'].plot()

# %%
LogReturn = np.log(kosdaqi.Close) - np.log(kosdaqi.Close.shift(1))
LogReturn.plot(linewidth=0.9)

# %%
macq_start_date = '2007-12-28'
macq_end_date = '2020-04-17'
macq = data.DataReader('088980.ks', 'yahoo', macq_start_date, macq_end_date)
macq.head(9)
macq['Close'].plot()

macq[macq['Close'] > 40000]
# Out:
#                     High           Low          Open         Close  Volume  \
# Date
# 2012-07-04  49790.601562  49790.601562  49790.601562  49790.601562     0.0
# 2012-07-05  49790.601562  49790.601562  49790.601562  49790.601562     0.0
# 2012-07-06  49790.601562  49790.601562  49790.601562  49790.601562     0.0
# 2012-07-09  49790.601562  49790.601562  49790.601562  49790.601562     0.0
# 2012-07-16  49790.601562  49790.601562  49790.601562  49790.601562     0.0
# 2012-07-25  49790.601562  49790.601562  49790.601562  49790.601562     0.0
# 2012-07-30  49790.601562  49790.601562  49790.601562  49790.601562     0.0
# 2012-09-04  49790.601562  49790.601562  49790.601562  49790.601562     0.0
#
#               Adj Close
# Date
# 2012-07-04  41261.09375
# 2012-07-05  41261.09375
# 2012-07-06  41261.09375
# 2012-07-09  41261.09375
# 2012-07-16  41261.09375
# 2012-07-25  41261.09375
# 2012-07-30  41261.09375
# 2012-09-04  41261.09375

# %%
macq = macq[macq['Close'] < 40000]
macq['Close'].plot()

# %%
shilla_start_date = '2007-12-28'
shilla_end_date = '2020-07-31'
shilla = data.DataReader('008775.ks', 'yahoo', shilla_start_date, shilla_end_date)
shilla.head(9)
shilla['Close'].plot()

# %%
shilla['Close'].plot(linewidth=0.5)

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis, norm
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## Time Series Plot
LogReturn = np.log(NASDAQ_data.Close) - np.log(NASDAQ_data.Close.shift(1))
LogReturn.plot(linewidth=0.5)

# %%
## Moments
LRmean = np.mean(LogReturn)  # LRmean = mean(LogReturn)
LRstd = np.std(LogReturn)    # LRstd = sd(LogReturn)
LRskew = skew(LogReturn)     # LRskew = skewness(LogReturn)
LRkurt = kurtosis(LogReturn) # LRkurt = kurtosis(LogReturn)

## Plot Histogram
plt.figure(figsize=(7, 7))     # win.graph(width=7, height =7)
hist = LogReturn.hist(bins=40) # hist(LogReturn , breaks =40, freq=FALSE , xlab="Log Return",ylab=" Relative Frequency",main ="")

plt.xlabel("Log Return")
plt.ylabel("Relative Frequency")

x = np.linspace(np.min(LogReturn), np.max(LogReturn), 101) # x = seq(from=min(LogReturn), to=max(LogReturn), by =0.001)
y = norm(LRmean,LRstd).pdf(x)
plt.plot(x,y, color='red') # lines(x, dnorm(x,LRmean ,LRstd),lwd=2,col="red")
plt.legend(['Normal pdf', 'Relative Freq'])# legend (" topright", c(" Relative Freq", "Normal pdf"), col=c(" black","red"), lwd =2)

# %%
df_data=shop_data

# %%
df_data.shape
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1310 entries, 2015-05-20 to 2020-07-31
# Data columns (total 6 columns):
# High         1310 non-null float64
# Low          1310 non-null float64
# Open         1310 non-null float64
# Close        1310 non-null float64
# Volume       1310 non-null int64
# Adj Close    1310 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 71.6 KB

# %%
df_data.count()
# Out:
# High         1310
# Low          1310
# Open         1310
# Close        1310
# Volume       1310
# Adj Close    1310
# dtype: int64

# %%
df_data.nunique()
# Out:
# High         1257
# Low          1257
# Open         1250
# Close        1263
# Volume       1288
# Adj Close    1263
# dtype: int64

# %%
type(df_data['High'])
df_data.iloc[0]
df_clean = df_data.copy()
df_clean.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2015-05-20  17.000000  17.000000  17.000000  17.000000         0  17.000000
# 2015-05-21  28.740000  24.110001  28.000000  25.680000  12303900  25.680000
# 2015-05-22  31.100000  26.000000  26.070000  28.309999   2841200  28.309999
# 2015-05-26  30.340000  29.080000  29.799999  29.650000    820200  29.650000
# 2015-05-27  30.809999  27.000000  30.670000  27.500000    797600  27.500000

# %%
df_clean.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
 missing 평균 채워넣기

# %%
df_clean.isnull().sum()
mean_df = round(df_clean.mean())
mean_df
# Out:
# High             183.0
# Low              175.0
# Open             179.0
# Close            179.0
# Volume       1660949.0
# Adj Close        179.0
# dtype: float64

# %%
df_clean['Close'].fillna(mean_df, inplace=True)

# %%
df_clean['Volume'].describe()
# Out:
# count    1.310000e+03
# mean     1.660949e+06
# std      1.553592e+06
# min      0.000000e+00
# 25%      7.644250e+05
# 50%      1.320550e+06
# 75%      2.085775e+06
# max      2.089590e+07
# Name: Volume, dtype: float64

# %%
#missing drop

df_clean = df_clean.dropna()

# %%
df_clean.boxplot()

# %%
df_clean['Vol_group']=np.nan
df_clean.head()


bins = list(range(0, 21000000, 700000))

df_clean['Vol_group']=pd.cut(shop_clean['Volume'], bins, right=False)

factor1= pd.qcut(df_clean['Volume'], 10, labels=np.arange(0, 10, +1))

df_clean['Vol_group']=pd.qcut(df_clean['Volume'], 10, labels=np.arange(0, 10, +1))

factor1
# Out:
# Date
# 2015-05-20    0
# 2015-05-21    9
# 2015-05-22    8
# 2015-05-26    2
# 2015-05-27    2
#              ..
# 2020-07-27    8
# 2020-07-28    9
# 2020-07-29    9
# 2020-07-30    8
# 2020-07-31    7
# Name: Volume, Length: 1310, dtype: category
# Categories (10, int64): [0 < 1 < 2 < 3 ... 6 < 7 < 8 < 9]

# %%
df_clean['Vol_group'].value_counts()
# Out:
# 9    131
# 8    131
# 7    131
# 6    131
# 5    131
# 4    131
# 3    131
# 2    131
# 1    131
# 0    131
# Name: Vol_group, dtype: int64

# %%
df_clean['Vol_group'].value_counts()
# Out:
# 9    131
# 8    131
# 7    131
# 6    131
# 5    131
# 4    131
# 3    131
# 2    131
# 1    131
# 0    131
# Name: Vol_group, dtype: int64

# %%
df_clean[(df_clean['Close'] > 1000) | (df_clean['High'] > 1000)].count()
# Out:
# High         14
# Low          14
# Open         14
# Close        14
# Volume       14
# Adj Close    14
# Vol_group    14
# dtype: int64

# %%
group_df_clean=df_clean.groupby(factor1)

# %%
df_clean.groupby('Vol_group').hist('Close')
# Out:
# Vol_group
# 0    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# 1    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# 2    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# 3    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# 4    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# 5    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# 6    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# 7    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# 8    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# 9    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# dtype: object

# %%
df_clean.plot.scatter('Close','Volume')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
df_clean.corr()
# Out:
#                High       Low      Open     Close    Volume  Adj Close
# High       1.000000  0.999406  0.999615  0.999548  0.412435   0.999548
# Low        0.999406  1.000000  0.999421  0.999575  0.400998   0.999575
# Open       0.999615  0.999421  1.000000  0.999014  0.407478   0.999014
# Close      0.999548  0.999575  0.999014  1.000000  0.406059   1.000000
# Volume     0.412435  0.400998  0.407478  0.406059  1.000000   0.406059
# Adj Close  0.999548  0.999575  0.999014  1.000000  0.406059   1.000000

# %%
df_clean.corr().style.background_gradient(cmap='autumn')
# Out:
# <style  type="text/css" >
#     #T_68335dc0_d44e_11ea_984e_d0817ad8aab7row0_col0 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_68335dc0_d44e_11ea_984e_d0817ad8aab7row0_col1 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_68335dc0_d44e_11ea_984e_d0817ad8aab7row0_col2 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_68335dc0_d44e_11ea_984e_d0817ad8aab7row0_col3 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_68335dc0_d44e_11ea_984e_d0817ad8aab7row0_col4 {
#             background-color:  #ff0400;
#             color:  #f1f1f1;
#         }    #T_68335dc0_d44e_11ea_984e_d0817ad8aab7row0_col5 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_68335dc0_d44e_11ea_984e_d0817ad8aab7row1_col0 {
#             background-color:  #ffff00;
#             color:  #000000;
# ...

# %%
df_clean[shop_clean['Vol_group'] >8].boxplot('Close')

# %%
#pairplots for all of the variables
# %matplotlib inline
import seaborn as sns; sns.set()
sns.pairplot(df_clean);

# %%
x = df_clean['Volume']
y = df_clean['Close']

plt.plot(x, y, 'o')

# %%
line_fitter = LinearRegression()
line_fitter.fit(x.values.reshape(-1,1), y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
line_fitter.predict([[500]])
# Out:
# array([91.85514588])

# %%
line_fitter.coef_
# Out:
# array([5.25211495e-05])

# %%
line_fitter.intercept_
# Out:
# 91.82888530319495

# %%
plt.plot(x, y, 'o')
plt.plot(x,line_fitter.predict(x.values.reshape(-1,1)))
plt.show()

# %%
trade volume의 변화에 따라 가격 변동 모형을 브라운 운동으로 한 번 예측해 볼 수 있어?
